# %% [markdown]
# ### 1. Importar les llibreries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import hashlib
import pickle
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

# %% [markdown]
# ### 2. Carregar el dataset

# %%
df = pd.read_csv('/Users/nicolakorff/Desktop/ML/IT_Academy/bank_dataset_wins.CSV')
df.head()
# Out:
#     age         job  marital  education default  balance housing loan  \
# 0  59.0      admin.  married  secondary      no     2343     yes   no
# 1  56.0      admin.  married  secondary      no       45      no   no
# 2  41.0  technician  married  secondary      no     1270     yes   no
# 3  55.0    services  married  secondary      no     2476     yes   no
# 4  54.0      admin.  married   tertiary      no      184      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes
# 3  unknown    5   may       579         1     -1         0  unknown     yes
# 4  unknown    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# ### 3. Divisió del dataset

# %%
# para modelos de clasificación, antes de dividir el conjunto, hay que analizar el balance entre las clases
# Dividir el dataset en conjuntos de entrenamiento y prueba
train, test = train_test_split(df, test_size=0.2, random_state=22)
print("Tamaño del conjunto de entrenamiento (train):", train.shape)
print("Tamaño del conjunto de prueba (test):", test.shape)
# Out:
# Tamaño del conjunto de entrenamiento (train): (8929, 17)
# Tamaño del conjunto de prueba (test): (2233, 17)

# %%
# Guardar los conjuntos en archivos CSV
train.to_csv('bank_dataset_train.csv', index=False)
test.to_csv('bank_dataset_test.csv', index=False)
# Chequear las primeras filas de ambos conjuntos
train.head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 843   44.0  technician  married  secondary      no      267      no   no
# 1899  47.0      admin.  married  secondary      no      663     yes  yes
# 7459  56.0     retired  married   tertiary      no     5769      no   no
# 2346  54.0  management  married   tertiary      no     1464      no   no
# 5673  40.0      admin.   single    unknown      no      355     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 843   cellular   22   aug       520         2     -1         0  unknown
# 1899  cellular   12   may       409         1    274         6    other
# 7459   unknown   20   jun        15         3     -1         0  unknown
# 2346  cellular   30   jun       157         1     -1         0  unknown
# 5673  cellular    7   apr       345         2    138         6    other
#
#      deposit
# 843      yes
# 1899     yes
# 7459      no
# 2346     yes
# 5673      no

# %%
test.head()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 1904  37.0       admin.   single    primary      no      912     yes   no
# 3113  52.0     services  married  secondary      no      659      no   no
# 1281  71.0      retired  married   tertiary      no      653      no   no
# 7856  29.0  blue-collar  married    primary      no       59     yes  yes
# 6757  28.0  blue-collar  married    primary      no      278     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 1904   cellular   12   may       637         3    328        22    other
# 3113   cellular   28   jan       390         4     93         1  success
# 1281  telephone   26   feb       367         1     -1         0  unknown
# 7856   cellular   29   jul       665         4     -1         0  unknown
# 6757  telephone   15   may        31         9    373         4    other
#
#      deposit
# 1904     yes
# 3113     yes
# 1281     yes
# 7856      no
# 6757      no

# %% [markdown]
# ### 4. Transformar variables categóriques

# %%
# Label Encoding para 'education', 'month', 'poutcome' 
# Ver los valores únicos en la columna 'month'
unique_month = train['month'].unique()
print(unique_month)
# Out:
# ['aug' 'may' 'jun' 'apr' 'jul' 'nov' 'jan' 'feb' 'mar' 'oct' 'sep' 'dec']

# %%
# Uso de OrdinalEncoder
train2=train
# Orden específico
month_order = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
# Configuramos el OrdinalEncoder con el orden deseado
ordinal_encoder = OrdinalEncoder(categories=[month_order])
# Ajustamos y transformamos la columna
train['month_encoded'] = ordinal_encoder.fit_transform(train[['month']])
train2.head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 843   44.0  technician  married  secondary      no      267      no   no
# 1899  47.0      admin.  married  secondary      no      663     yes  yes
# 7459  56.0     retired  married   tertiary      no     5769      no   no
# 2346  54.0  management  married   tertiary      no     1464      no   no
# 5673  40.0      admin.   single    unknown      no      355     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 843   cellular   22   aug       520         2     -1         0  unknown
# 1899  cellular   12   may       409         1    274         6    other
# 7459   unknown   20   jun        15         3     -1         0  unknown
# 2346  cellular   30   jun       157         1     -1         0  unknown
# 5673  cellular    7   apr       345         2    138         6    other
#
#      deposit  month_encoded
# 843      yes            7.0
# 1899     yes            4.0
# 7459      no            5.0
# 2346     yes            5.0
# 5673      no            3.0

# %%
# Ver los valores únicos en la columna 'education'
unique_education = train2['education'].unique()
print(unique_education)
# Out:
# ['secondary' 'tertiary' 'unknown' 'primary' nan]

# %%
# Uso de mapeo manual
# Especificamos el orden que queremos con un diccionario
education_map = {'primary': 1, 'secondary': 2, 'tertiary': 3, 'unknown': 0}

# Aplicamos el mapeo a la columna
train2['education_encoded'] = train2['education'].map(education_map)
train2.head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 843   44.0  technician  married  secondary      no      267      no   no
# 1899  47.0      admin.  married  secondary      no      663     yes  yes
# 7459  56.0     retired  married   tertiary      no     5769      no   no
# 2346  54.0  management  married   tertiary      no     1464      no   no
# 5673  40.0      admin.   single    unknown      no      355     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 843   cellular   22   aug       520         2     -1         0  unknown
# 1899  cellular   12   may       409         1    274         6    other
# 7459   unknown   20   jun        15         3     -1         0  unknown
# 2346  cellular   30   jun       157         1     -1         0  unknown
# 5673  cellular    7   apr       345         2    138         6    other
#
#      deposit  month_encoded  education_encoded
# 843      yes            7.0                2.0
# 1899     yes            4.0                2.0
# 7459      no            5.0                3.0
# 2346     yes            5.0                3.0
# 5673      no            3.0                0.0

# %%
# Ver los valores únicos en la columna 'poutcome'
unique_poutcome = train2['poutcome'].unique()
print(unique_poutcome)
# Out:
# ['unknown' 'other' 'success' 'failure']

# %%
# Uso de mapeo manual
# Especificamos el orden que queremos con un diccionario
poutcome_map = {'success': 3, 'failure': 2, 'other': 1, 'unknown': 0}

# Aplicamos el mapeo a la columna
train2['poutcome_encoded'] = train2['poutcome'].map(education_map)
train2.head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 843   44.0  technician  married  secondary      no      267      no   no
# 1899  47.0      admin.  married  secondary      no      663     yes  yes
# 7459  56.0     retired  married   tertiary      no     5769      no   no
# 2346  54.0  management  married   tertiary      no     1464      no   no
# 5673  40.0      admin.   single    unknown      no      355     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 843   cellular   22   aug       520         2     -1         0  unknown
# 1899  cellular   12   may       409         1    274         6    other
# 7459   unknown   20   jun        15         3     -1         0  unknown
# 2346  cellular   30   jun       157         1     -1         0  unknown
# 5673  cellular    7   apr       345         2    138         6    other
#
#      deposit  month_encoded  education_encoded  poutcome_encoded
# 843      yes            7.0                2.0               0.0
# 1899     yes            4.0                2.0               NaN
# 7459      no            5.0                3.0               0.0
# 2346     yes            5.0                3.0               0.0
# 5673      no            3.0                0.0               NaN

# %%
# One-Hot Encoding para 'loan', 'housing', 'deafult', 'deposit', 'marital', 'job'
# Nuevo DataFrame
train3 = train2

# %%
# Utilitzar get_dummies per a 'loan', 'housing', 'deafult', 'deposit'
train3 = pd.get_dummies(train3, columns=['loan'], prefix='loan')
train3 = pd.get_dummies(train3, columns=['housing'], prefix='housing')
train3 = pd.get_dummies(train3, columns=['default'], prefix='default')
train3 = pd.get_dummies(train3, columns=['deposit'], prefix='deposit')
train3.head()
# Out:
#        age         job  marital  education  balance   contact  day month  \
# 843   44.0  technician  married  secondary      267  cellular   22   aug
# 1899  47.0      admin.  married  secondary      663  cellular   12   may
# 7459  56.0     retired  married   tertiary     5769   unknown   20   jun
# 2346  54.0  management  married   tertiary     1464  cellular   30   jun
# 5673  40.0      admin.   single    unknown      355  cellular    7   apr
#
#       duration  campaign  ...  education_encoded  poutcome_encoded loan_no  \
# 843        520         2  ...                2.0               0.0    True
# 1899       409         1  ...                2.0               NaN   False
# 7459        15         3  ...                3.0               0.0    True
# 2346       157         1  ...                3.0               0.0    True
# 5673       345         2  ...                0.0               NaN    True
#
#       loan_yes  housing_no  housing_yes  default_no  default_yes  deposit_no  \
# 843      False        True        False        True        False       False
# 1899      True       False         True        True        False       False
# 7459     False        True        False        True        False        True
# 2346     False        True        False        True        False       False
# 5673     False       False         True        True        False        True
#
#       deposit_yes
# 843          True
# 1899         True
# 7459        False
# 2346         True
# 5673        False
#
# [5 rows x 24 columns]

# %%
train4=train3
# Inicializamos el OneHotEncoder
encoder = OneHotEncoder(drop='first')  # 'drop="first"' elimina una categoría para evitar multicolinealidad

# Aplicamos el encoder a la columna 'marital' y lo convertimos en un array
marital_encoded = encoder.fit_transform(train4[['marital']]).toarray()

# Creamos un DataFrame con las columnas codificadas y las unimos al DataFrame original
marital_encoded_train4 = pd.DataFrame(marital_encoded, columns=encoder.get_feature_names_out(['marital']))
train4 = pd.concat([train4, marital_encoded_train4], axis=1)

# %%
# Inicializamos el OneHotEncoder
encoder = OneHotEncoder(drop='first')  # 'drop="first"' elimina una categoría para evitar multicolinealidad

# Aplicamos el encoder a la columna 'marital' y lo convertimos en un array
job_encoded = encoder.fit_transform(train4[['job']]).toarray()

# Creamos un DataFrame con las columnas codificadas y las unimos al DataFrame original
job_encoded_train4 = pd.DataFrame(job_encoded, columns=encoder.get_feature_names_out(['job']))
train4 = pd.concat([train4, job_encoded_train4], axis=1)

# %%
train4.head()
# Out:
#        age         job  marital  education  balance   contact   day month  \
# 843   44.0  technician  married  secondary    267.0  cellular  22.0   aug
# 1899  47.0      admin.  married  secondary    663.0  cellular  12.0   may
# 7459  56.0     retired  married   tertiary   5769.0   unknown  20.0   jun
# 2346  54.0  management  married   tertiary   1464.0  cellular  30.0   jun
# 5673  40.0      admin.   single    unknown    355.0  cellular   7.0   apr
#
#       duration  campaign  ...  job_housemaid  job_management job_retired  \
# 843      520.0       2.0  ...            0.0             1.0         0.0
# 1899     409.0       1.0  ...            0.0             1.0         0.0
# 7459      15.0       3.0  ...            0.0             0.0         0.0
# 2346     157.0       1.0  ...            0.0             1.0         0.0
# 5673     345.0       2.0  ...            0.0             0.0         0.0
#
#       job_self-employed  job_services  job_student job_technician  \
# 843                 0.0           0.0          0.0            0.0
# 1899                0.0           0.0          0.0            0.0
# 7459                0.0           0.0          0.0            0.0
# 2346                0.0           0.0          0.0            0.0
# 5673                0.0           0.0          1.0            0.0
#
#      job_unemployed job_unknown job_nan
# 843             0.0         0.0     0.0
# 1899            0.0         0.0     0.0
# 7459            0.0         0.0     0.0
# 2346            0.0         0.0     0.0
# 5673            0.0         0.0     0.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ### 5. Estandarització o Normalització de les dades

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
# Inicializamos el StandardScaler
scale = StandardScaler()
# Seleccionamos las columnas
X = df[['Weight', 'Volume']]

scaledX = scale.fit_transform(X)

print(scaledX)

# %% [markdown]
# ### 6. Reduir la dimensionalitat
